# %%
import pandas as pd 
import json

# %%
d1 = pd.read_csv("ImdbName.csv")
d1
# Out:
#              nconst        primaryName birthYear deathYear  \
# 0         nm0000001       Fred Astaire      1899      1987
# 1         nm0000002      Lauren Bacall      1924      2014
# 2         nm0000003    Brigitte Bardot      1934        \N
# 3         nm0000004       John Belushi      1949      1982
# 4         nm0000005     Ingmar Bergman      1918      2007
# ...             ...                ...       ...       ...
# 1048570  nm10129437      Adela Hurtado        \N        \N
# 1048571  nm10129438        Eric Becker        \N        \N
# 1048572  nm10129439  Matthew Lee Aaron        \N        \N
# 1048573   nm1012943      Matteo Bigoni        \N        \N
# 1048574  nm10129440  Alexandre Ionescu        \N        \N
#
#                                          primaryProfession  \
# 0                           soundtrack,actor,miscellaneous
# 1                                       actress,soundtrack
# 2                      actress,soundtrack,music_department
# ...

# %%
d2 = pd.read_csv("ImdbTitleAkas.csv")
d2
# Out:
# /opt/anaconda3/envs/VIB-pytorch/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            titleId  ordering                      title region language  \
# 0        tt0000001         1                 Карменсіта     UA       \N
# 1        tt0000001         2                 Carmencita     DE       \N
# 2        tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3        tt0000001         4                 Καρμενσίτα     GR       \N
# 4        tt0000001         5                 Карменсита     RU       \N
# ...            ...       ...                        ...    ...      ...
# 1048570  tt0177858        23                    W lipcu     PL       \N
# 1048571  tt0177858        24      Η Ιουλία τον Αύγουστο     GR       \N
# 1048572  tt0177858        25                   En julio     UY       \N
# ...

# %%
d3 = pd.read_csv("ImdbTitleBasics.csv").set_index("tconst")
d3=pd.get_dummies(d3["genres"])
d3
# Out:
# /opt/anaconda3/envs/VIB-pytorch/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             Action  Action,Adult  Action,Adult,Adventure  \
# tconst
# tt0000001        0             0                       0
# tt0000002        0             0                       0
# tt0000003        0             0                       0
# tt0000004        0             0                       0
# tt0000005        0             0                       0
# ...            ...           ...                     ...
# tt10140376       0             0                       0
# tt10140378       0             0                       0
# tt1014037        0             0                       0
# tt10140380       0             0                       0
# tt10140382       0             0                       0
#
# ...

# %%
d4 = pd.read_csv("ImdbTitleRatings.csv").set_index("tconst")
d4
# Out:
#            averageRating  numVotes
# tconst
# tt0000001            5.6      1694
# tt0000002            6.0       210
# tt0000003            6.5      1441
# tt0000004            6.1       122
# tt0000005            6.1      2240
# ...                  ...       ...
# tt7512616            9.0         5
# tt7512624            5.5       931
# tt7512632            3.4        33
# tt7512636            6.4        22
# tt7512670            7.0        49
#
# [1048575 rows x 2 columns]

# %%
d5 = pd.read_csv("ImdbTitleCrew.csv").set_index("tconst")
d5
# Out:
#                       directors  \
# tconst
# tt0000001             nm0005690
# tt0000002             nm0721526
# tt0000003             nm0721526
# tt0000004             nm0721526
# tt0000005             nm0005690
# ...                         ...
# tt10140376            nm6250318
# tt10140378            nm4172614
# tt1014037   nm0065781,nm0928139
# tt10140380            nm0619375
# tt10140382            nm5733692
#
#                                                       writers
# tconst
# tt0000001                                                  \N
# tt0000002                                                  \N
# tt0000003                                                  \N
# tt0000004                                                  \N
# tt0000005                                                  \N
# ...                                                       ...
# tt10140376                                          nm4446121
# ...

# %%
d6 = pd.read_csv("ImdbTitlePrincipals.csv").set_index("tconst")
d6
# Out:
#            ordering     nconst         category                      job  \
# tconst
# tt0000001         1  nm1588970             self                       \N
# tt0000001         2  nm0005690         director                       \N
# tt0000001         3  nm0374658  cinematographer  director of photography
# tt0000002         1  nm0721526         director                       \N
# tt0000002         2  nm1335271         composer                       \N
# ...             ...        ...              ...                      ...
# tt0123372         1  nm0691995          actress                       \N
# tt0123372         2  nm0530422          actress                       \N
# tt0123372         3  nm0096022          actress                       \N
# tt0123372         4  nm0351734          actress                       \N
# tt0123372         5  nm0711859         director                       \N
#
#                                          characters
# tconst
# ...

# %%
titles = pd.concat([d3,d4], axis=1)
titles = titles[["primaryTitle","startYear","genres","averageRating"]]
titles["directors"] = 0
titles
# Out:
#                      primaryTitle startYear                    genres  \
# tconst
# tt0000001              Carmencita      1894         Documentary,Short
# tt0000002  Le clown et ses chiens      1892           Animation,Short
# tt0000003          Pauvre Pierrot      1892  Animation,Comedy,Romance
# tt0000004             Un bon bock      1892           Animation,Short
# tt0000005        Blacksmith Scene      1893              Comedy,Short
# ...                           ...       ...                       ...
# tt7512616                     NaN       NaN                       NaN
# tt7512624                     NaN       NaN                       NaN
# tt7512632                     NaN       NaN                       NaN
# tt7512636                     NaN       NaN                       NaN
# tt7512670                     NaN       NaN                       NaN
#
#            averageRating  directors
# tconst
# tt0000001            5.6          0
# ...

# %%
titles1 = titles.iloc[0:100,]
df0 = titles1.to_json(orient='records')

save_file = open("trial1.json", "w")  
json.dump(df0, save_file, indent = 6)  
save_file.close()

# %%
titles1 = titles[[:100,]]
df = titles.to_json()
# Out:
#   File "/var/folders/lh/s3wp6f1j0wg0fnq0l5fttycc0000gn/T/ipykernel_24494/3860547628.py", line 1
#     titles1 = titles[[:100,]]
#                       ^
# SyntaxError: invalid syntax

# %%
save_file = open("movietitle.json", "w")  
json.dump(df, save_file, indent = 6)  
save_file.close()

# %%
import os

os.path.realpath("trial1.json")
# Out:
# '/Users/sunhuiming/Desktop/trabajo-final 2/spark/trial1.json'

# %%
df2 = d2.to_json()
file1 = open("titlecoverage.json", "w")  
json.dump(df2, file1, indent = 6)  
save_file.close()

# %%
df = pd.DataFrame(data)

# Convert DataFrame to JSON
json_data = df.to_json(orient='records')

# Save JSON data to a file
with open('output.json', 'w') as file:
    file.write(json_data)
